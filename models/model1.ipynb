# %%
# Import libraries
import joblib

import pandas as pd
import numpy as np
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error

# %%
# Load files
data_path = ''
train = pd.read_csv(data_path + 'Train.csv')
test = pd.read_csv(data_path + 'Test.csv')
# sample_submission = pd.read_csv(data_path + 'SampleSubmission.csv')
# var_desc = pd.read_csv(data_path + 'VariableDescription.csv')

# %%
train.head()
# Out:
#                 ID District      Block  CultLand  CropCultLand  \
# 0  ID_GTFAC7PEVWQ9  Nalanda  Noorsarai        45            40
# 1  ID_TK40ARLSPOKS  Nalanda     Rajgir        26            26
# 2  ID_1FJY2CRIMLZZ     Gaya      Gurua        10            10
# 3  ID_I3IPXS4DB7NE     Gaya      Gurua        15            15
# 4  ID_4T8YQWXWHB4A  Nalanda  Noorsarai        60            60
#
#                                LandPreparationMethod CropTillageDate  \
# 0               TractorPlough FourWheelTracRotavator      2022-07-20
# 1  WetTillagePuddling TractorPlough FourWheelTrac...      2022-07-18
# 2               TractorPlough FourWheelTracRotavator      2022-06-30
# 3               TractorPlough FourWheelTracRotavator      2022-06-16
# 4                   TractorPlough WetTillagePuddling      2022-07-19
#
#    CropTillageDepth         CropEstMethod RcNursEstDate  ... Harv_method  \
# 0                 5  Manual_PuddledRandom    2022-06-27  ...     machine
# ...

# %%
test.head()
# Out:
#                 ID  District   Block  CultLand  CropCultLand  \
# 0  ID_F9XXEXN2ADR2     Jamui  Khaira        20            13
# 1  ID_SO3VW2X4QO93     Jamui  Khaira        25            25
# 2  ID_UKUQ7JM8E894   Nalanda  Rajgir        30            30
# 3  ID_QUISMWEZR2H4  Vaishali   Mahua        15            10
# 4  ID_25JGI455VKCZ   Nalanda  Rajgir        30            10
#
#                                LandPreparationMethod CropTillageDate  \
# 0                                      TractorPlough      2022-07-24
# 1                                      TractorPlough      2022-07-24
# 2  WetTillagePuddling TractorPlough FourWheelTrac...      2022-07-07
# 3  WetTillagePuddling TractorPlough BullockPlough...      2022-07-04
# 4  WetTillagePuddling TractorPlough FourWheelTrac...      2022-07-21
#
#    CropTillageDepth         CropEstMethod RcNursEstDate  ...  \
# 0                 4    Manual_PuddledLine    2022-07-03  ...
# ...

# %%
train = train[['CultLand', 'CropCultLand', 'LandPreparationMethod', 'CropTillageDepth','CropEstMethod', 'SeedlingsPerPit','TransplantingIrrigationHours', 'TransplantingIrrigationSource','TransplantingIrrigationPowerSource','StandingWater', 'CropOrgFYM', 'PCropSolidOrgFertAppMethod', 'NoFertilizerAppln', 'CropbasalFerts', 'BasalDAP', 'MineralFertAppMethod', 'BasalUrea', 'Harv_method', 'Threshing_method', 'Residue_length', 'Acre', 'Yield']]
train.head()
# Out:
#    CultLand  CropCultLand                              LandPreparationMethod  \
# 0        45            40               TractorPlough FourWheelTracRotavator
# 1        26            26  WetTillagePuddling TractorPlough FourWheelTrac...
# 2        10            10               TractorPlough FourWheelTracRotavator
# 3        15            15               TractorPlough FourWheelTracRotavator
# 4        60            60                   TractorPlough WetTillagePuddling
#
#    CropTillageDepth         CropEstMethod  SeedlingsPerPit  \
# 0                 5  Manual_PuddledRandom              2.0
# 1                 5  Manual_PuddledRandom              2.0
# 2                 6  Manual_PuddledRandom              2.0
# 3                 6  Manual_PuddledRandom              2.0
# 4                 4  Manual_PuddledRandom              2.0
#
#    TransplantingIrrigationHours TransplantingIrrigationSource  \
# 0                           5.0                        Boring
# ...

# %%
train.head()
# Out:
#    CultLand  CropCultLand                              LandPreparationMethod  \
# 0        45            40               TractorPlough FourWheelTracRotavator
# 1        26            26  WetTillagePuddling TractorPlough FourWheelTrac...
# 2        10            10               TractorPlough FourWheelTracRotavator
# 3        15            15               TractorPlough FourWheelTracRotavator
# 4        60            60                   TractorPlough WetTillagePuddling
#
#    CropTillageDepth         CropEstMethod  SeedlingsPerPit  \
# 0                 5  Manual_PuddledRandom              2.0
# 1                 5  Manual_PuddledRandom              2.0
# 2                 6  Manual_PuddledRandom              2.0
# 3                 6  Manual_PuddledRandom              2.0
# 4                 4  Manual_PuddledRandom              2.0
#
#    TransplantingIrrigationHours TransplantingIrrigationSource  \
# 0                           5.0                        Boring
# ...

# %%
# Import label encoder 
from sklearn import preprocessing 

# label_encoder object knows 
# how to understand word labels. 
label_encoder = preprocessing.LabelEncoder()

# %%
train= train.apply(label_encoder.fit_transform)

# %%
train.head()
# Out:
#    CultLand  CropCultLand  LandPreparationMethod  CropTillageDepth  \
# 0        43            37                     18                 4
# 1        25            25                     41                 4
# 2         9             9                     18                 5
# 3        14            14                     18                 5
# 4        55            52                     24                 3
#
#    CropEstMethod  SeedlingsPerPit  TransplantingIrrigationHours  \
# 0              3                1                             4
# 1              3                1                             4
# 2              3                1                             3
# 3              3                1                            43
# 4              3                1                             8
#
#    TransplantingIrrigationSource  TransplantingIrrigationPowerSource  \
# 0                              0                                   1
# ...

# %%
X = train.iloc[:, :-1]  # All columns except the last one
y = train.iloc[:, -1]

# %%
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.2,random_state=7)

# %%
train.head()
# Out:
#    CultLand  CropCultLand  LandPreparationMethod  CropTillageDepth  \
# 0        43            37                     18                 4
# 1        25            25                     41                 4
# 2         9             9                     18                 5
# 3        14            14                     18                 5
# 4        55            52                     24                 3
#
#    CropEstMethod  SeedlingsPerPit  TransplantingIrrigationHours  \
# 0              3                1                             4
# 1              3                1                             4
# 2              3                1                             3
# 3              3                1                            43
# 4              3                1                             8
#
#    TransplantingIrrigationSource  TransplantingIrrigationPowerSource  \
# 0                              0                                   1
# ...

# %%
# %pip install xgboost
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
model=RandomForestRegressor()
model.fit(X_train,y_train)
# from xgboost import XGBRegressor

# my_model = XGBRegressor()
# # Add silent=True to avoid printing out updates with each cycle
# my_model.fit(X_train, y_train, verbose=False)
# Out:
# RandomForestRegressor()

# %%
y_pred=model.predict(X_test)

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score

# %%
from sklearn.metrics import mean_squared_error
mean_squared_error(y_test, y_pred)
# Out:
# 1181.118296471437

# %%
joblib.dump(model, 'model.pkl')
# Out:
# ['model.pkl']
